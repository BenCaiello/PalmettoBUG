# %% [markdown]
# # Image Processing
#
# Start from this notebook before doing the others in this folder! The other notebooks depend on the directory structure set up in this one.

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn.objects as so
import seaborn as sns

import tifffile as tf

import palmettobug as pbug
import isosegdenoise as iSD

# %% [markdown]
# ### CHANGE The following directory to match an existing directory on your computer if you are testing this tutorial on your own machine!

# %%
my_computer_path =  "C:/Users/Default/Desktop"  ## CHANGE This DIRECTORY to match an existing directory on your computer if you testing this tutorial on your own machine!

# %% [markdown]
# ## Set up a new directory and project
#
# Here we:
#
#     1). Set up a fresh directory on our computer that we wll place the project
#
#     2). fetch the example data from PalmettoBUG into the project directory
#
#     3). load the directory into a pbug.ImageAnalysis object

# %%
#pbug.fetch_IMC_example(my_computer_path)
project_directory = my_computer_path + "/Example_IMC"

# %%
resolutions = [1.0, 1.0]    ## in micrometers. 1 micron is standard IMC resolution
ImageAnalysis = pbug.imc_entrypoint(project_directory, resolutions =  resolutions, from_mcds = True)    ## The example data is available as .tiff files, because the mcd files are too large to bundle with the program easily.

# %% [markdown]
# ## Next, set up the panel file:

# %%
display(ImageAnalysis.panel)
# Out:
#     channel          name  keep  segmentation
# 0      I127          127I     0           NaN
# 1     Xe131         131Xe     0           NaN
# 2     Ba132         132Ba     0           NaN
# 3     Ba138         138Ba     0           NaN
# 4     Pr141          aSMA     1           NaN
# 5     Nd142    p-selectin     1           NaN
# 6     Nd143      Vimentin     1           NaN
# 7     Nd144          CD14     1           NaN
# 8     Nd145          CD31     1           NaN
# 9     Nd146          CD16     1           NaN
# 10    Nd148   Pan-Keratin     1           NaN
# 11    Sm149         CD11b     1           NaN
# 12    Eu151         CD163     1           NaN
# 13    Sm152          CD45     1           NaN
# 14    Eu153         CD206     1           NaN
# 15    Sm154          CCL2     1           NaN
# 16    Gd155         FoxP3     1           NaN
# 17    Gd156           CD4     1           NaN
# 18    Gd158    E-cadherin     1           NaN
# 19    Tb159          CD68     1           NaN
# 20    Gd160         CD66b     1           NaN
# 21    Dy161          CD20     1           NaN
# 22    Dy162           CD8     1           NaN
# 23    Dy163  Vitrionectin     1           NaN
# 24    Dy164         CD32b     1           NaN
# 25    Er167     GranzymeB     1           1.0
# 26    Er168         Ki-67     1           NaN
# 27    Tm169    Collagen-1     1           NaN
# 28    Er170           CD3     1           NaN
# 29    Yb171     HistoneH3     1           1.0
# 30    Yb172  Beta-Catenin     1           1.0
# 31    Yb173        CD45RO     1           2.0
# 32    Yb174        HLA-DR     1           2.0
# 33  BCKG190       190BCKG     0           2.0
# 34    Ir191          DNA1     1           2.0
# 35    Ir193          DNA2     1           2.0
# 36    Pt195          Seg1     1           2.0
# 37    Pt196          Seg2     1           2.0
# 38    Pt198          Seg3     1           2.0

# %%
'''
Seeing the panel with the keep == 0 channels dropped is useful, as this will be the order of the channels in the .tiff files in /images/img, and therefore
the actual order of channels expected by certain steps of the program (such as pixel classification) when dealing with the images
## However -- in this case -- all the channels are to be kept, so it makes no difference
'''
#  ImageAnalysis.panel[ImageAnalysis.panel['keep'] == 1].reset_index().drop('index', axis = 1)
display()

# %%
'''
We must select our segmentation markers
'''
ImageAnalysis.panel.loc[25, "segmentation"] = 1         # H3
ImageAnalysis.panel.loc[29:31, "segmentation"] = 1      # DNA1 / 2
ImageAnalysis.panel.loc[31:, "segmentation"] = 2        # Seg 1-3

# %%
### The panel needs to be exported to the disc for record keeping, for loading the segmentation / denoiser ImageAnalysis class, and for reloading from the same directory with the same panel settings
ImageAnalysis.panel_write()  ## not needed if using a TableLaunch GUI to enter panel file values

# %% [markdown]
# ## Now we can convert the /raw files to image files
#
# This step does 4 things:
#
#     1). Moves data from the /raw folder in the project directory --> to the /images/img folder
#
#     2). If starting from MCDs, unpacks 1 .ome.tiff file in /images/img for every ROI in the MCDs
#
#     3). If hpf > 0,  performs hot pixel filtering (see steinbock hot pixel filtering for what this does) to each image exported to /images/img
#
#     4). Only exports channels with keep == 1 in the panel file
#
# In this case, because we are starting from .ome.tiff files & all the channels have keep == 1, this effectively only runs hot pixel filtering while copying the example .
# ome.tiff files from /raw to the images/img folder.

# %%
## convert MCDs ---> ome.tiff files. 
    ## with from_mcds = False, would convert Tiff --> ome.tiff, with the primary purpose being to hot pixel filter & to drop channels with keep = 0  in the panel file
ImageAnalysis.raw_to_img(hpf = 50)    # hpf = 50 is the default from steinbock

## do not worry about "Key not found: list index out of range" messages -- this is normal as part of reading / writing ome.tiffs (unfortunately, this is a print statement inside the dependency that handles
                                                                                                                         #     ome.tiff files, so it is not possible remove without changing that dependency)

# %% [markdown]
# ## Now do Segmentation
#
# (in isosegdenoise)
#
# Here we load the project directory in iSD's paralell ImageAnalysis class, then perform deepcell segmentation.
#
# To perform deepcell segmentation, we must:
#
#     1). the images we what to segment (image_source_directory) -- this is typically the project's /images/img folder, unless additional image denoising / processing has been applied.
#         It is also trivial to process the images outisde of palmettobug entirely, and then pass in those images to this function, as long as the order & number of channels remains the
#         same inside the .tiff file.
#
#     2). the names of the image(s) from that folder to segment. Can be ['ALL'] to segment all images in the folder, or can be a list of individual files in the folder.
#
#     3). where we want the segmentation masks to be written (mask_output_directory), this is the /masks/deepcell folder in the GUI and this example. However, there is no restriction
#         on where the output files can be written, so long as the destination folder can be created with os.mkdir(mask_output_directory).

# %%
## initialize denoise / esgmentation ImageAnalysis:
seg_ImageAnalysis = iSD.imc_entrypoint(directory = project_directory, resolutions = resolutions, from_mcds = False)

# %%
'''
Select Deepcell segmentation parameters
'''
image_source_directory = ImageAnalysis.directory_object.img_dir + "/img"   
image_list = ['ALL']    ## either takes ['ALL'] (default) to segment all images, or a list of images (such as from os.listdir()), and will segment the first as a test

mask_output_directory = ImageAnalysis.directory_object.masks_dir + "/deepcell"

re_do = True           ## If set to False (default), will skip already segmented images (will not overwrite if image with same name already exists in output) 
                        ## Only used is image_list == ['All']

# %%
'''
Do Deepcell segmentation!
'''
seg_ImageAnalysis.deepcell_segment(image_folder = image_source_directory, 
                                   output_folder = mask_output_directory, 
                                   image_list = image_list, 
                                   re_do = re_do,
                                  is_torch = False)
# Out:
# Downloading data from https://deepcell-data.s3-us-west-1.amazonaws.com/saved-models/MultiplexSegmentation-9.tar.gz
# 96885295/96885295 [==============================] - 45s 0us/step
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 539ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 539ms/step
# 1/1 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 1s 556ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 547ms/step
# 1/1 [==============================] - 1s 559ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 529ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 538ms/step
# 1/1 [==============================] - 1s 543ms/step
# CRC_1_ROI_001 has been Segmented, with 2311 masks in it!
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 534ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 1s 556ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 558ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 542ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 555ms/step
# 1/1 [==============================] - 1s 558ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 536ms/step
# 1/1 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 542ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 558ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 555ms/step
# 1/1 [==============================] - 1s 544ms/step
# CRC_1_ROI_002 has been Segmented, with 5714 masks in it!
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 537ms/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 1s 547ms/step
# 1/1 [==============================] - 1s 556ms/step
# 1/1 [==============================] - 1s 559ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 559ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 547ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 567ms/step
# CRC_2_ROI_001 has been Segmented, with 5566 masks in it!
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 547ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 579ms/step
# CRC_2_ROI_002 has been Segmented, with 2401 masks in it!
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 555ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 561ms/step
# CRC_2_ROI_003 has been Segmented, with 2716 masks in it!
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 542ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 603ms/step
# CRC_2_ROI_004 has been Segmented, with 1606 masks in it!
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 556ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 556ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 560ms/step
# CRC_3_ROI_001 has been Segmented, with 3166 masks in it!
# 1/1 [==============================] - 1s 559ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 687ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 559ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 559ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 618ms/step
# 1/1 [==============================] - 1s 805ms/step
# 1/1 [==============================] - 1s 950ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 558ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 555ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 570ms/step
# CRC_3_ROI_002 has been Segmented, with 4733 masks in it!
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 559ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 555ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 542ms/step
# 1/1 [==============================] - 1s 560ms/step
# CRC_3_ROI_003 has been Segmented, with 1391 masks in it!
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 542ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 556ms/step
# 1/1 [==============================] - 1s 558ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 1s 536ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 542ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 558ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 558ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 576ms/step
# CRC_3_ROI_004 has been Segmented, with 5238 masks in it!

# %%
masks = os.listdir(mask_output_directory)
tf.imshow(tf.imread(mask_output_directory + "/" + masks[0]))
# Out:
# (<Figure size 988.8x604.8 with 2 Axes>,
#  <Axes: >,
#  <matplotlib.image.AxesImage at 0x298ce95e890>)

# %% [markdown]
# ## Next make region measurements from the Segmentation masks.
#
# This requires:
#
#     1). an Analysis directory must be set up. This is a folder structure where the later Single-cell Analysis can be conducted.
#         There can be multiple Analyses per one project (if, say, you were testing whether or not denoising certain channels made a
#         difference to the analysis, you could have a separate Analysis for each), so they are by default placed in the /Analyses folder
#         of the project directory, only needing a unique folder name to be provided.
#
#     2). The folder of images to make measurements off of    (input_img_folder)
#
#     3). The folder of segmentation masks to define the regions where measurements will be taken     (input_mask_folder)
#
#     4). The aggregate statistic to use on the values of the channels in the regions, such mean or median.
#
#     5). The output folder for the intensities csv and the regionprops csvs (output_intensities_folder and output_regions_folder).
#
#             -- These csv's are the same / similar as from steinbock's region measurement steps (on which this was derived)
#                 One csv of each type is generated for every image in the input_img_folder
#
#             -- The intensities csv's contain the aggregate intensity of each channel within each segmentation region
#
#             -- The regionprops csv's contain details about the segmentation masks, such as details related to the shape and
#                 location of each mask.
#
# While the input and output folders typically follow a set structure -- as they do in this example as well as in the GUI -- there is no theoretical restriction
# on where you could input images / masks from or write them to, so there is flexbility in how this can be used.

# %%
''' Name and setup the Analysis directory '''

analysis_folder_name = "MyAmazingAnalysis"
ImageAnalysis.directory_object.make_analysis_dirs(analysis_folder_name)

# %%
'''
Make measurements of the segmented / masked regions
'''

input_img_folder = ImageAnalysis.directory_object.img_dir + "/img"
input_mask_folder = ImageAnalysis.directory_object.masks_dir + "/example_deepcell_masks" ## this replicates the masks perfectly (from a tensorflow-based 
                                                                                         ## segmentation) to match the example data
                                                                                    ## change to ImageAnalysis.directory_object.masks_dir + "/deepcell"
                                                                                    ## in order to use the masks we created in the preceding cells
                                                                                    ## these may not perfectly match the example masks due to differences 
                                                                                    ## in GPU rounding / system architecture, torch vs tensorflow, etc.
output_intensities_folder = ImageAnalysis.directory_object.intensities_dir   # (default)
output_regions_folder = ImageAnalysis.directory_object.regionprops_dir       # (default)


statistic_options = ["sum", "min", "max", "mean","median","std","var"]
statistic = "mean"    ## this is the default, and rarely would you want to deviate from this

re_do = True    ## Determines if existing .csv's in the outputs folder wil be redone / overwritten or not. Naturally, this does not matter the first thme it is run.

ImageAnalysis.make_segmentation_measurements(input_img_folder, 
                                             input_mask_folder, 
                                             statistic = statistic, 
                                             re_do = re_do, 
                                             output_intensities_folder = output_intensities_folder, 
                                             output_regions_folder = output_regions_folder)
# Out:
# CRC_1_ROI_001.ome intensity & region properties csv's have been printed!
# CRC_1_ROI_002.ome intensity & region properties csv's have been printed!
# CRC_2_ROI_001.ome intensity & region properties csv's have been printed!
# CRC_2_ROI_002.ome intensity & region properties csv's have been printed!
# CRC_2_ROI_003.ome intensity & region properties csv's have been printed!
# CRC_2_ROI_004.ome intensity & region properties csv's have been printed!
# CRC_3_ROI_001.ome intensity & region properties csv's have been printed!
# CRC_3_ROI_002.ome intensity & region properties csv's have been printed!
# CRC_3_ROI_003.ome intensity & region properties csv's have been printed!
# CRC_3_ROI_004.ome intensity & region properties csv's have been printed!

# %% [markdown]
# ## Next, make the panel and metadata files for the Analysis
#
# Preliminary panel and metadata can be easily generated with the to_analysis method, but will still need to be edited for actual use in a Single cell analysis.
#
# Data that can't be automatically supplied by this method include:
#
#     1). metadata --> patient_id and condition columns must be supplied by the user
#
#     2). Analysis_panel --> marker_class (type, state, none)
#
# However, in this case the example data comes bundled with a fully set-up analysis panel and metadata file, you we don't need to provide this information.

# %% [markdown]
# ## Note: These cells will create 2 pop-up windows to assist you in editing the metadata / panel files!
#
# If you want to replicate the documentation, click Accept and Return without making any edits in the pop up windows

# %%
'''
Now, generate preliminary metadata / Analysis panel files -- if you have not created them already in another program like excel -- then edit
'''
panel, metadata, panel_path, metadata_path = ImageAnalysis.to_analysis(metadata_from_save = True)     ## we set metadata_from_save to True because of how the example is loaded from the package.

## Uncomment to show the intial panels:
# display(metadata)
# display(panel)

# %%
'''TableLaunches supply as easy & intuitive way to edit the preliminary versions of these files:'''
export_path =  panel_path
pbug.TableLaunch(dataframe = panel, table_type = "Analysis_panel", export_path = export_path,
             labels_editable = True,  width = 1.5, height = 1).mainloop()

export_path =  metadata_path
pbug.TableLaunch(dataframe = metadata, table_type = "metadata", export_path = export_path,
             labels_editable = True,  width = 1.5, height = 1).mainloop()

'''However, these files are already set up and do not need to be edited further, unless desired to test out the affects of different settings)'''
display()

# %% [markdown]
# ## Load the analysis directory into the PalmettoBUG.Analysis class to begin Single-cell analysis

# %%
'''
Now that the proper analysis directory strucutre has been made and populated with .fcs files and the metadata and panel files, we can initiate an analysis
'''

Analysis_experiment = pbug.Analysis()
Analysis_experiment.load_data(ImageAnalysis.directory_object.Analysis_internal_dir)  ## Note how the directory here is the "internal_dir" 
#Analysis_experiment.load_fcs()                                                                                            # --> in your system's file explorer you see this as the "/main" folder inside the analysis folder

# %%
'''
Doing a single-cell data analysis in PalmettoBUG will be covered more in a different notebook -- but for this notebook I will generate a countplot just to show that
we have successfully entered the Analysis portion of the software!
'''
fig = Analysis_experiment.plot_cell_counts(group_by = "sample_id", color_by = "condition", filename = "countplot.png")
fig
